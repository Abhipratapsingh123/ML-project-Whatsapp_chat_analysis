# %%
import re
import pandas as pd
import warnings
warnings.filterwarnings(action = 'ignore')

# %%
print(21)
# Out:
# 21

# %%
f = open("whatsapp_chat_analysis.txt",'r',encoding= 'utf-8')

# %%
data = f.read()

# %%
print(data)
# Out:
# 13/05/24, 10:19 - Messages and calls are end-to-end encrypted. No one outside of this chat, not even WhatsApp, can read or listen to them. Tap to learn more.
# 27/03/24, 17:44 - You created this group
# 13/05/24, 10:19 - Akshat added you
# 13/05/24, 10:19 - Akshat: This message was deleted
# 13/05/24, 16:05 - Abhi Pratap Singh: <Media omitted>
# 13/05/24, 16:05 - Abhi Pratap Singh: <Media omitted>
# 13/05/24, 16:05 - Abhi Pratap Singh: <Media omitted>
# 13/05/24, 16:05 - Abhi Pratap Singh: <Media omitted>
# 13/05/24, 16:05 - Abhi Pratap Singh: <Media omitted>
# 13/05/24, 16:20 - RKB added Atharv
# 13/05/24, 16:20 - Anirudh Negi: .
# 13/05/24, 16:20 - Anirudh Negi: .
# 13/05/24, 16:21 - You're now an admin
# 13/05/24, 16:35 - Anirudh Negi: This message was deleted
# 13/05/24, 16:36 - Anirudh Negi: This message was deleted
# 13/05/24, 18:53 - Abhi Pratap Singh: https://www.instagram.com/reel/C62ndV4unqp/?igsh=dWMxeW1scnZ0OHZ0
# 13/05/24, 18:53 - RKB: Real <This message was edited>
# ...

# %%
pattern = '\d{1,2}/\d{1,2}/\d{2,4},\s\d{1,2}:\d{2}\s-\s'

# %%
messages = re.split(pattern, data)[1:]
messages
# Out:
# ['Messages and calls are end-to-end encrypted. No one outside of this chat, not even WhatsApp, can read or listen to them. Tap to learn more.\n',
#  'You created this group\n',
#  'Akshat added you\n',
#  'Akshat: This message was deleted\n',
#  'Abhi Pratap Singh: <Media omitted>\n',
#  'Abhi Pratap Singh: <Media omitted>\n',
#  'Abhi Pratap Singh: <Media omitted>\n',
#  'Abhi Pratap Singh: <Media omitted>\n',
#  'Abhi Pratap Singh: <Media omitted>\n',
#  'RKB added Atharv\n',
#  'Anirudh Negi: .\n',
#  'Anirudh Negi: .\n',
#  "You're now an admin\n",
#  'Anirudh Negi: This message was deleted\n',
#  'Anirudh Negi: This message was deleted\n',
#  'Abhi Pratap Singh: https://www.instagram.com/reel/C62ndV4unqp/?igsh=dWMxeW1scnZ0OHZ0\n',
#  'RKB: Real <This message was edited>\n',
#  'Abhi Pratap Singh: You deleted this message\n',
#  'Akshat: Oye\n',
#  'Akshat: Mujhe wow water park ki location bhejiyo\n',
#  'RKB: <Media omitted>\n',
#  'Anirudh Negi: <Media omitted>\n',
# ...

# %%
dates = re.findall(pattern, data)

# %%
dates
# Out:
# ['13/05/24, 10:19 - ',
#  '27/03/24, 17:44 - ',
#  '13/05/24, 10:19 - ',
#  '13/05/24, 10:19 - ',
#  '13/05/24, 16:05 - ',
#  '13/05/24, 16:05 - ',
#  '13/05/24, 16:05 - ',
#  '13/05/24, 16:05 - ',
#  '13/05/24, 16:05 - ',
#  '13/05/24, 16:20 - ',
#  '13/05/24, 16:20 - ',
#  '13/05/24, 16:20 - ',
#  '13/05/24, 16:21 - ',
#  '13/05/24, 16:35 - ',
#  '13/05/24, 16:36 - ',
#  '13/05/24, 18:53 - ',
#  '13/05/24, 18:53 - ',
#  '13/05/24, 19:04 - ',
#  '13/05/24, 19:04 - ',
#  '13/05/24, 19:05 - ',
#  '13/05/24, 19:06 - ',
#  '13/05/24, 19:07 - ',
#  '13/05/24, 19:07 - ',
#  '13/05/24, 19:08 - ',
#  '13/05/24, 19:08 - ',
#  '13/05/24, 19:08 - ',
#  '13/05/24, 19:08 - ',
#  '13/05/24, 19:08 - ',
#  '13/05/24, 19:08 - ',
#  '13/05/24, 19:08 - ',
#  '13/05/24, 19:08 - ',
#  '13/05/24, 19:09 - ',
#  '13/05/24, 19:09 - ',
#  '13/05/24, 19:09 - ',
#  '13/05/24, 19:09 - ',
#  '13/05/24, 19:10 - ',
#  '13/05/24, 19:10 - ',
#  '13/05/24, 19:10 - ',
#  '13/05/24, 19:10 - ',
#  '13/05/24, 19:10 - ',
# ...

# %%
# creating dataframe
df = pd.DataFrame({'user_message': messages, 'date': dates})

# convert message_date type
df['date'] = pd.to_datetime(df['date'], format='%d/%m/%y, %H:%M - ')

df.head()
# Out:
#                                         user_message                date
# 0  Messages and calls are end-to-end encrypted. N... 2024-05-13 10:19:00
# 1                           You created this group\n 2024-03-27 17:44:00
# 2                                 Akshat added you\n 2024-05-13 10:19:00
# 3                 Akshat: This message was deleted\n 2024-05-13 10:19:00
# 4               Abhi Pratap Singh: <Media omitted>\n 2024-05-13 16:05:00

# %%
df.shape
# Out:
# (9706, 2)

# %%
# separating users and messages

users = []
messages = []

for message in df['user_message']:
    entry = re.split('([\w\W]+?):\s', message)
    if entry[1:]:
        users.append(entry[1])
        messages.append(entry[2])
    else:
        users.append('group_notification')
        messages.append(entry[0])

df['users'] = users
df['messages'] = messages
df.head()
# Out:
#                                         user_message                date  \
# 0  Messages and calls are end-to-end encrypted. N... 2024-05-13 10:19:00
# 1                           You created this group\n 2024-03-27 17:44:00
# 2                                 Akshat added you\n 2024-05-13 10:19:00
# 3                 Akshat: This message was deleted\n 2024-05-13 10:19:00
# 4               Abhi Pratap Singh: <Media omitted>\n 2024-05-13 16:05:00
#
#                 users                                           messages
# 0  group_notification  Messages and calls are end-to-end encrypted. N...
# 1  group_notification                           You created this group\n
# 2  group_notification                                 Akshat added you\n
# 3              Akshat                         This message was deleted\n
# 4   Abhi Pratap Singh                                  <Media omitted>\n

# %%
# deleting user_message column

df.drop(columns=['user_message'], inplace = True)

# %%
df.head()
# Out:
#                  date               users  \
# 0 2024-05-13 10:19:00  group_notification
# 1 2024-03-27 17:44:00  group_notification
# 2 2024-05-13 10:19:00  group_notification
# 3 2024-05-13 10:19:00              Akshat
# 4 2024-05-13 16:05:00   Abhi Pratap Singh
#
#                                             messages
# 0  Messages and calls are end-to-end encrypted. N...
# 1                           You created this group\n
# 2                                 Akshat added you\n
# 3                         This message was deleted\n
# 4                                  <Media omitted>\n

# %%
df['year'] = df['date'].dt.year

# %%
df['month'] = df['date'].dt.month_name()

# %%
df['day'] = df['date'].dt.day

# %%
df['hour'] = df['date'].dt.hour

# %%
df['minute'] = df['date'].dt.minute

# %%
df.head()
# Out:
#                  date               users  \
# 0 2024-05-13 10:19:00  group_notification
# 1 2024-03-27 17:44:00  group_notification
# 2 2024-05-13 10:19:00  group_notification
# 3 2024-05-13 10:19:00              Akshat
# 4 2024-05-13 16:05:00   Abhi Pratap Singh
#
#                                             messages  year  month  day  hour  \
# 0  Messages and calls are end-to-end encrypted. N...  2024    May   13    10
# 1                           You created this group\n  2024  March   27    17
# 2                                 Akshat added you\n  2024    May   13    10
# 3                         This message was deleted\n  2024    May   13    10
# 4                                  <Media omitted>\n  2024    May   13    16
#
#    minute
# 0      19
# 1      44
# 2      19
# 3      19
# 4       5

# %%
# extracting total words 
words =[]
for message in df['messages']:
    words.extend(message.split())

# %%
len(words)
# Out:
# 42322

# %%
# for extracting links in messages
from urlextract import URLExtract

# %%
extractor = URLExtract()

# %%
new__df = round((df['users'].value_counts()/ df.shape[0]) * 100,2).reset_index().rename(
        columns={"users":"name","count": "percent"})

# %%
new__df
# Out:
#                  name  percent
# 0                 RKB    28.77
# 1        Anirudh Negi    24.06
# 2              Akshat    22.24
# 3   Abhi Pratap Singh    13.14
# 4              Atharv     6.42
# 5              Chirag     4.58
# 6  group_notification     0.79

# %%
temp = df[df['users'] !='group_notification']
temp = temp[temp['messages'] != "<Media omitted>\n"]
temp.head()
# Out:
#                   date         users                    messages  year month  \
# 3  2024-05-13 10:19:00        Akshat  This message was deleted\n  2024   May
# 10 2024-05-13 16:20:00  Anirudh Negi                         .\n  2024   May
# 11 2024-05-13 16:20:00  Anirudh Negi                         .\n  2024   May
# 13 2024-05-13 16:35:00  Anirudh Negi  This message was deleted\n  2024   May
# 14 2024-05-13 16:36:00  Anirudh Negi  This message was deleted\n  2024   May
#
#     day  hour  minute
# 3    13    10      19
# 10   13    16      20
# 11   13    16      20
# 13   13    16      35
# 14   13    16      36

# %%
f = open('stop_hinglish.txt','r')
stop_words = f.read()
print(stop_words)
# Out:
# .
# ..
# ...
# ?
# -
# --
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9
# 0
# a
# aadi
# aaj
# aap
# aapne
# aata
# aati
# aaya
# aaye
# ab
# abbe
# abbey
# abe
# abhi
# able
# about
# above
# accha
# according
# accordingly
# acha
# achcha
# across
# actually
# after
# afterwards
# again
# against
# agar
# ain
# aint
# ain't
# aisa
# aise
# aisi
# alag
# all
# allow
# allows
# almost
# alone
# along
# already
# also
# although
# always
# am
# among
# amongst
# an
# and
# andar
# another
# any
# anybody
# anyhow
# anyone
# anything
# anyway
# anyways
# anywhere
# ap
# apan
# apart
# apna
# apnaa
# apne
# apni
# appear
# are
# aren
# arent
# aren't
# around
# arre
# as
# aside
# ask
# asking
# at
# aur
# avum
# aya
# aye
# baad
# baar
# bad
# bahut
# bana
# banae
# banai
# banao
# banaya
# banaye
# banayi
# banda
# bande
# bandi
# bane
# bani
# bas
# bata
# batao
# bc
# be
# became
# because
# become
# becomes
# becoming
# been
# before
# beforehand
# behind
# being
# below
# beside
# besides
# ...

# %%
#Most used words in chats
words_2 = []
for message in temp['messages']:
    for word in message.lower().split():
        if word not in stop_words:
            words_2.append(word)

# %%
import emoji

# %%
emojis =[]
for message in df['messages']:
    emojis.extend([c for c in message if c in emoji.EMOJI_DATA])

# %%
from collections import Counter

# %%
pd.DataFrame(Counter(emojis).most_common(len(Counter(emojis))))
# Out:
#     0      1
# 0   🤣  29368
# 1   😂    192
# 2   🏻     28
# 3   🐉     25
# 4   😭     25
# .. ..    ...
# 60  😨      1
# 61  📈      1
# 62  🧎      1
# 63  🏽      1
# 64  😐      1
#
# [65 rows x 2 columns]

# %%
df['month_num']= df['date'].dt.month

# %%
df
# Out:
#                     date               users  \
# 0    2024-05-13 10:19:00  group_notification
# 1    2024-03-27 17:44:00  group_notification
# 2    2024-05-13 10:19:00  group_notification
# 3    2024-05-13 10:19:00              Akshat
# 4    2024-05-13 16:05:00   Abhi Pratap Singh
# ...                  ...                 ...
# 9701 2024-09-02 19:31:00              Akshat
# 9702 2024-09-02 19:31:00              Akshat
# 9703 2024-09-02 19:32:00   Abhi Pratap Singh
# 9704 2024-09-02 19:32:00              Akshat
# 9705 2024-09-04 11:55:00                 RKB
#
#                                                messages  year      month  day  \
# 0     Messages and calls are end-to-end encrypted. N...  2024        May   13
# 1                              You created this group\n  2024      March   27
# 2                                    Akshat added you\n  2024        May   13
# 3                            This message was deleted\n  2024        May   13
# ...

# %%
timeline = df.groupby(['year','month_num','month']).count()['messages'].reset_index()

# %%
timeline
# Out:
#    year  month_num      month  messages
# 0  2024          3      March         1
# 1  2024          5        May      5683
# 2  2024          6       June       947
# 3  2024          7       July      1518
# 4  2024          8     August      1253
# 5  2024          9  September       304

# %%
time =[]
for i in range(timeline.shape[0]):
    time.append(timeline['month'][i]+'-'+str(timeline['year'][i]))

# %%
timeline['time'] = time

# %%
timeline
# Out:
#    year  month_num      month  messages            time
# 0  2024          3      March         1      March-2024
# 1  2024          5        May      5683        May-2024
# 2  2024          6       June       947       June-2024
# 3  2024          7       July      1518       July-2024
# 4  2024          8     August      1253     August-2024
# 5  2024          9  September       304  September-2024

# %%
plt.plot(timeline['time'],timeline['messages'])
plt.show()
